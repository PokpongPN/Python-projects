# %% [markdown]
# # Pound Sterling Exchange Rate Data from an API

# %%
# import package
from requests import get
from time import sleep
import pandas as pd
import json
import requests

# %%
# request data from api
url = "https://v6.exchangerate-api.com/v6/941ca88a79e6813058dd5bd0/latest/GBP"
requests.get(url)
# Out:
# <Response [200]>

# %%
result = requests.get(url)
result.text
# Out:
# '{\n "result":"success",\n "documentation":"https://www.exchangerate-api.com/docs",\n "terms_of_use":"https://www.exchangerate-api.com/terms",\n "time_last_update_unix":1699574401,\n "time_last_update_utc":"Fri, 10 Nov 2023 00:00:01 +0000",\n "time_next_update_unix":1699660801,\n "time_next_update_utc":"Sat, 11 Nov 2023 00:00:01 +0000",\n "base_code":"GBP",\n "conversion_rates":{\n  "GBP":1,\n  "AED":4.4980,\n  "AFN":90.4564,\n  "ALL":120.7719,\n  "AMD":493.8271,\n  "ANG":2.1924,\n  "AOA":1027.0318,\n  "ARS":428.7095,\n  "AUD":1.9173,\n  "AWG":2.1924,\n  "AZN":2.0792,\n  "BAM":2.2421,\n  "BBD":2.4496,\n  "BDT":134.5125,\n  "BGN":2.2422,\n  "BHD":0.4605,\n  "BIF":3480.7982,\n  "BMD":1.2248,\n  "BND":1.6649,\n  "BOB":8.4455,\n  "BRL":6.0281,\n  "BSD":1.2248,\n  "BTN":102.1255,\n  "BWP":16.7253,\n  "BYN":3.9769,\n  "BZD":2.4496,\n  "CAD":1.6890,\n  "CDF":3059.7339,\n  "CHF":1.1042,\n  "CLP":1109.8759,\n  "CNY":8.9318,\n  "COP":5069.2661,\n  "CRC":648.2545,\n  "CUP":29.3947,\n  "CVE":126
# ...

# %%
result.json()
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1699574401,
#  'time_last_update_utc': 'Fri, 10 Nov 2023 00:00:01 +0000',
#  'time_next_update_unix': 1699660801,
#  'time_next_update_utc': 'Sat, 11 Nov 2023 00:00:01 +0000',
#  'base_code': 'GBP',
#  'conversion_rates': {'GBP': 1,
#   'AED': 4.498,
#   'AFN': 90.4564,
#   'ALL': 120.7719,
#   'AMD': 493.8271,
#   'ANG': 2.1924,
#   'AOA': 1027.0318,
#   'ARS': 428.7095,
#   'AUD': 1.9173,
#   'AWG': 2.1924,
#   'AZN': 2.0792,
#   'BAM': 2.2421,
#   'BBD': 2.4496,
#   'BDT': 134.5125,
#   'BGN': 2.2422,
#   'BHD': 0.4605,
#   'BIF': 3480.7982,
#   'BMD': 1.2248,
#   'BND': 1.6649,
#   'BOB': 8.4455,
#   'BRL': 6.0281,
#   'BSD': 1.2248,
#   'BTN': 102.1255,
#   'BWP': 16.7253,
#   'BYN': 3.9769,
#   'BZD': 2.4496,
#   'CAD': 1.689,
#   'CDF': 3059.7339,
#   'CHF': 1.1042,
#   'CLP': 1109.8759,
#   'CNY': 8.9318,
# ...

# %%
data_json = result.json()
data_json['base_code']
# Out:
# 'GBP'

# %%
df = pd.DataFrame.from_dict(data_json, orient='columns')
df
# Out:
#       result                          documentation  \
# AED  success  https://www.exchangerate-api.com/docs
# AFN  success  https://www.exchangerate-api.com/docs
# ALL  success  https://www.exchangerate-api.com/docs
# AMD  success  https://www.exchangerate-api.com/docs
# ANG  success  https://www.exchangerate-api.com/docs
# ..       ...                                    ...
# XPF  success  https://www.exchangerate-api.com/docs
# YER  success  https://www.exchangerate-api.com/docs
# ZAR  success  https://www.exchangerate-api.com/docs
# ZMW  success  https://www.exchangerate-api.com/docs
# ZWL  success  https://www.exchangerate-api.com/docs
#
#                                terms_of_use  time_last_update_unix  \
# AED  https://www.exchangerate-api.com/terms             1699574401
# AFN  https://www.exchangerate-api.com/terms             1699574401
# ALL  https://www.exchangerate-api.com/terms             1699574401
# ...

# %%
df.to_csv("exchange_rate_GBP.csv")
